# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"41766113845","type":"CreateEvent","actor":{"id":56844125,"login":"SonoranBrian","display_login":"SonoranBrian","gravatar_id":"","url":"https://api.github.com/users/SonoranBrian","avatar_url":"https://avatars.githubusercontent.com/u/56844125?"},"repo":{"id":800155716,"name":"Sonoran-Software/SonoranRadio_Windows","url":"https://api.github.com/repos/Sonoran-Software/SonoranRadio_Windows"},"payload":{"ref":"v2.5.3","ref_type":"tag","master_branch":"master","description":"SonoranRadio\'s Windows Desktop Application","pusher_type":"user"},"public":true,"created_at":"2024-09-09T20:14:05Z","org":{"id":56844144,"login":"Sonoran-Software","gravatar_id":"","url":"https://api.github.com/orgs/Sonoran-Software","avatar_url":"https://avatars.githubusercontent.com/u/56844144?"}},{"id":"41766113814","type":"PullRequestEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_
# ...

# %%
r.json()
# Out:
# [{'id': '41766113845',
#   'type': 'CreateEvent',
#   'actor': {'id': 56844125,
#    'login': 'SonoranBrian',
#    'display_login': 'SonoranBrian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SonoranBrian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56844125?'},
#   'repo': {'id': 800155716,
#    'name': 'Sonoran-Software/SonoranRadio_Windows',
#    'url': 'https://api.github.com/repos/Sonoran-Software/SonoranRadio_Windows'},
#   'payload': {'ref': 'v2.5.3',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': "SonoranRadio's Windows Desktop Application",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-09-09T20:14:05Z',
#   'org': {'id': 56844144,
#    'login': 'Sonoran-Software',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Sonoran-Software',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56844144?'}},
#  {'id': '41766113814',
#   'type': 'PullRequestEvent',
# ...

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
gitrequest = requests.get('https://github.com/gabrulho')

# %%
gitrequest.url
# Out:
# 'https://github.com/gabrulho'

# %%
gitrequest.text
# Out:
# '\n\n<!DOCTYPE html>\n<html\n  lang="en"\n  \n  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"\n  data-a11y-animated-images="system" data-a11y-link-underlines="true"\n  >\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-3e154969b9f9.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-9c5b7a476542.css" /><link data-color-theme="dark_dimmed" crossor
# ...

# %%
# especificando a versão da API

headers ={'X-Github-Api-Version': '2022-11-28'}

# %%
api_base_url ='https://api.github.com'
owner = 'amzn' # nome do alvo da extração de dados 
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# Autenticação

# %%
acess_token = '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'
headers = {'Authorization': 'Bearer' + acess_token,
           'X-Github-Api-Version': '2022-11-28'}

# %%
api_base_url ='https://api.github.com'
owner = 'amzn' # nome do alvo da extração de dados 
url = f'{api_base_url}/users/{owner}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list =[]
for page_num in range (1,7):
    try: 
        url_page = f'{url}?page={page_num}' 
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except: 
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(repos_list)
# Out:
# 6

# %%
len(repos_list[5])
# Out:
# 8

# %% [markdown]
# Transformando dados

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-template'

# %%
repos_name = []
for page in repos_list:
    for  repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs']

# %%
len(repos_name)
# Out:
# 158

# %%
repos_lang = []
for page in repos_list:
    for  repo in page:
        repos_lang.append(repo['language'])

# %%
repos_lang
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'Python',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  'TypeScript',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
# ...

# %%
len(repos_lang)
# Out:
# 158

# %% [markdown]
# DataFrame

# %%
pip install --upgrade pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data_amz = pd.DataFrame()
data_amz['Repository_name'] = repos_name
data_amz['Languages'] = repos_lang

# %%
data_amz
# Out:
#                  Repository_name         Languages
# 0                        .github              None
# 1        ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-template            Smarty
# 3                     alexa-coho        JavaScript
# 4            alexa-skills-kit-js              None
# ..                           ...               ...
# 153             zeek-plugin-enip              Zeek
# 154         zeek-plugin-profinet              Zeek
# 155           zeek-plugin-s7comm              Zeek
# 156              zeek-plugin-tds              Zeek
# 157               zero-shot-rlhr            Python
#
# [158 rows x 2 columns]

# %% [markdown]
# Salvando o dataframe

# %%
data_amz.to_csv('amazon.csv')
